# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
service = QiskitRuntimeService()

# %%
backend = service.get_backend('ibm_torino')

# %%
import kaleidoscope as kal

# %%
from kaleidoscope.qiskit.backends import system_gate_map
# Out:
# ---------------------------------------------------------------------------
# KaleidoscopeError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from kaleidoscope.qiskit.backends import system_gate_map
#
# File ~/mambaforge/envs/qiskit-one/lib/python3.12/site-packages/kaleidoscope/qiskit/__init__.py:22
#      19 from kaleidoscope.errors import KaleidoscopeError
#      21 if not HAS_QISKIT:
# ---> 22     raise KaleidoscopeError('Must install qiskit-terra, qiskit-aer, and qiskit-ibmq-provider.')
#      24 from .backends.mpl import *
#      25 from .backends.interactive import system_error_map, system_gate_map
#
# KaleidoscopeError: Must install qiskit-terra, qiskit-aer, and qiskit-ibmq-provider.
